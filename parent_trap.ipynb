# %%
# !pip list
# Out:
# Package                   Version
# ------------------------- -----------
# asttokens                 3.0.0
# attrs                     25.3.0
# comm                      0.2.3
# contourpy                 1.3.3
# cycler                    0.12.1
# debugpy                   1.8.16
# decorator                 5.2.1
# et_xmlfile                2.0.0
# executing                 2.2.0
# fastjsonschema            2.21.2
# fonttools                 4.59.1
# ipykernel                 6.30.1
# ipython                   9.4.0
# ipython_pygments_lexers   1.1.1
# jedi                      0.19.2
# jsonschema                4.25.1
# jsonschema-specifications 2025.4.1
# jupyter_client            8.6.3
# jupyter_core              5.8.1
# kiwisolver                1.4.9
# matplotlib                3.10.5
# matplotlib-inline         0.1.7
# narwhals                  2.1.2
# nbformat                  5.10.4
# nest-asyncio              1.6.0
# numpy                     2.3.2
# ...

# %%
import pandas as pd
df = pd.read_csv("cleaned_draft_history_corrected.csv")
df.head(15)
# Out:
#     PickInRound                      Player                             Team  \
# 0             1  Christian McCaffrey SF, RB               The Bowers that be
# 1             2         Breece Hall NYJ, RB                   Breeces Pieces
# 2             3         CeeDee Lamb Dal, WR                  Spin that Drake
# 3             4      Bijan Robinson Atl, RB                          DreamZz
# 4             5         Tyreek Hill Mia, WR                         The Hill
# 5             6   Amon-Ra St. Brown Det, WR              Mostert On The Beat
# 6             7       Ja'Marr Chase Cin, WR  The Battle of the JPs commences
# 7             8     Jonathan Taylor Ind, RB              Joel Embiid Express
# 8             9      Saquon Barkley Phi, RB                Mack Attack Combo
# 9            10    Justin Jefferson Min, WR                 Waist Management
# 10           11        Jahmyr Gibbs Det, RB      White Dudes For Harris, Son
# ...
